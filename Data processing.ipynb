# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('daily-minimum-temperatures-in-me.csv', infer_datetime_format=True, parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#            Daily minimum temperatures
# Date
# 1981-01-01                       20.7
# 1981-01-02                       17.9
# 1981-01-03                       18.8
# 1981-01-04                       14.6
# 1981-01-05                       15.8

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
px.line(df, x = df.index, y = 'Daily minimum temperatures')
# Out:
# <div>                            <div id="daf6524b-b991-4169-af72-97fe6ed8fa3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daf6524b-b991-4169-af72-97fe6ed8fa3e")) {                    Plotly.newPlot(                        "daf6524b-b991-4169-af72-97fe6ed8fa3e",                        [{"hovertemplate": "Date=%{x}<br>Daily minimum temperatures=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["1981-01-01T00:00:00", "1981-01-02T00:00:00", "1981-01-03T00:00:00", "1981-01-04T00:00:00", "1981-01-05T00:00:00", "1981-01-06T00:00:00", "1981-01-07T00:00:00", "1981-01-08T00:00:00", "1981-01-09T00:00:00", "1981-01-10T00:00:00", "1981-01-11T0
# ...

# %%
a = df[df.index.year == 1981]
a.head()
# Out:
#            Daily minimum temperatures
# Date
# 1981-01-01                       20.7
# 1981-01-02                       17.9
# 1981-01-03                       18.8
# 1981-01-04                       14.6
# 1981-01-05                       15.8

# %%
b = pd.read_csv('https://www.kaggle.com/shenba/time-series-datasets?select=daily-minimum-temperatures-in-me.csv')
b.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-85166636a1b5> in <module>
# ----> 1 b = pd.read_csv('https://www.kaggle.com/shenba/time-series-datasets?select=daily-minimum-temperatures-in-me.csv')
#       2 b.head()
#
# ...
